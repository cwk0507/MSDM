# %% [markdown]
# # API practice homework
#
# First read the API document about the covid data written by the UK government in
#
# https://coronavirus.data.gov.uk/details/developers-guide.
#
# Take a look to these things before start:
# 1. What is the main end node of this API?
# 2. Which parameters are required to pass into `requests.get()`?
# 3. Do you need a request header?
# 4. Do you need to go through any authentication process?
# 5. Do you need to deal with pagination?
#
#
# **Question:** Write a HTTP request by `requests.get()` to fetch some data:
#
# - The daily number of people receiving the first and second dose in Scotland.
# - The daily cummulative number of people receiving the first and second dose in Scotland.
#
# _Hint: You need to search the whole site (not only the develoer's page) to find out what are the metrics' names for the vaccine data._
#
# Checking: The oldest data available is from 10-Jan-2021.

# %%
import requests
import json
import pandas as pd

node = 'https://api.coronavirus.data.gov.uk/v1/data'

filters = {'areaType':'nation','areaName':'scotland'}

structure = {'date':'date',
             'DailyFirstDose':'newPeopleVaccinatedFirstDoseByPublishDate',
             'DailySecondDose':'newPeopleVaccinatedSecondDoseByPublishDate',
             'CumFirstDose':'cumPeopleVaccinatedFirstDoseByPublishDate',
             'CumSecondDose':'cumPeopleVaccinatedSecondDoseByPublishDate'
             }

parameters = {
    "filters": str.join(';',[field+'='+value for (field,value) in filters.items()]), 
    "structure": json.dumps(structure)
}

r = requests.get(node, params=parameters)

#json pretty print
print(json.dumps(r.json(),indent=4))
print()

#dataframe
df = pd.DataFrame(r.json()['data'])
df = df.set_index('date').sort_index()
print('Scraped data in table format:')
print(df)
# Out:
# {
#     "length": 26,
#     "maxPageLimit": 2500,
#     "data": [
#         {
#             "date": "2021-02-04",
#             "DailyFirstDose": 48165,
#             "DailySecondDose": 498,
#             "CumFirstDose": 742512,
#             "CumSecondDose": 9529
#         },
#         {
#             "date": "2021-02-03",
#             "DailyFirstDose": 45085,
#             "DailySecondDose": 273,
#             "CumFirstDose": 694347,
#             "CumSecondDose": 9031
#         },
#         {
#             "date": "2021-02-02",
#             "DailyFirstDose": 38484,
#             "DailySecondDose": 413,
#             "CumFirstDose": 649262,
#             "CumSecondDose": 8758
#         },
#         {
#             "date": "2021-02-01",
#             "DailyFirstDose": 34881,
#             "DailySecondDose": 496,
#             "CumFirstDose": 610778,
#             "CumSecondDose": 8345
#         },
#         {
#             "date": "2021-01-31",
#             "DailyFirstDose": 9628,
#             "DailySecondDose": 55,
#             "CumFirstDose": 575897,
#             "CumSecondDose": 7849
#         },
#         {
#             "date": "2021-01-30",
#             "DailyFirstDose": 22899,
#             "DailySecondDose": 156,
#             "CumFirstDose": 566269,
#             "CumSecondDose": 7794
#         },
#         {
#             "date": "2021-01-29",
#             "DailyFirstDose": 27515,
#             "DailySecondDose": 543,
#             "CumFirstDose": 543370,
#             "CumSecondDose": 7638
#         },
#         {
#             "date": "2021-01-28",
#             "DailyFirstDose": 24197,
#             "DailySecondDose": 312,
#             "CumFirstDose": 515855,
#             "CumSecondDose": 7095
#         },
#         {
#             "date": "2021-01-27",
#             "DailyFirstDose": 29566,
#             "DailySecondDose": 187,
#             "CumFirstDose": 491658,
#             "CumSecondDose": 6783
#         },
#         {
#             "date": "2021-01-26",
#             "DailyFirstDose": 24192,
#             "DailySecondDose": 536,
#             "CumFirstDose": 462092,
#             "CumSecondDose": 6596
#         },
#         {
#             "date": "2021-01-25",
#             "DailyFirstDose": 22498,
#             "DailySecondDose": 522,
#             "CumFirstDose": 437900,
#             "CumSecondDose": 6060
#         },
#         {
#             "date": "2021-01-24",
#             "DailyFirstDose": 11364,
#             "DailySecondDose": 155,
#             "CumFirstDose": 415402,
#             "CumSecondDose": 5538
#         },
#         {
#             "date": "2021-01-23",
#             "DailyFirstDose": 23371,
#             "DailySecondDose": 195,
#             "CumFirstDose": 404038,
#             "CumSecondDose": 5383
#         },
#         {
#             "date": "2021-01-22",
#             "DailyFirstDose": 22213,
#             "DailySecondDose": 499,
#             "CumFirstDose": 380667,
#             "CumSecondDose": 5188
#         },
#         {
#             "date": "2021-01-21",
#             "DailyFirstDose": 23583,
#             "DailySecondDose": 223,
#             "CumFirstDose": 358454,
#             "CumSecondDose": 4689
#         },
#         {
#             "date": "2021-01-20",
#             "DailyFirstDose": 24962,
#             "DailySecondDose": 296,
#             "CumFirstDose": 334871,
#             "CumSecondDose": 4466
#         },
#         {
#             "date": "2021-01-19",
#             "DailyFirstDose": 25327,
#             "DailySecondDose": 284,
#             "CumFirstDose": 309909,
#             "CumSecondDose": 4170
#         },
#         {
#             "date": "2021-01-18",
#             "DailyFirstDose": 19591,
#             "DailySecondDose": 188,
#             "CumFirstDose": 284582,
#             "CumSecondDose": 3886
#         },
#         {
#             "date": "2021-01-17",
#             "DailyFirstDose": 40151,
#             "DailySecondDose": 367,
#             "CumFirstDose": 264991,
#             "CumSecondDose": 3698
#         },
#         {
#             "date": "2021-01-16",
#             "DailyFirstDose": 0,
#             "DailySecondDose": 0,
#             "CumFirstDose": 224840,
#             "CumSecondDose": 3331
#         },
#         {
#             "date": "2021-01-15",
#             "DailyFirstDose": 0,
#             "DailySecondDose": 0,
#             "CumFirstDose": 224840,
#             "CumSecondDose": 3331
#         },
#         {
#             "date": "2021-01-14",
#             "DailyFirstDose": 16633,
#             "DailySecondDose": 141,
#             "CumFirstDose": 224840,
#             "CumSecondDose": 3331
#         },
#         {
#             "date": "2021-01-13",
#             "DailyFirstDose": 16242,
#             "DailySecondDose": 200,
#             "CumFirstDose": 208207,
#             "CumSecondDose": 3190
#         },
#         {
#             "date": "2021-01-12",
#             "DailyFirstDose": 16023,
#             "DailySecondDose": 133,
#             "CumFirstDose": 191965,
#             "CumSecondDose": 2990
#         },
#         {
#             "date": "2021-01-11",
#             "DailyFirstDose": 12565,
#             "DailySecondDose": 99,
#             "CumFirstDose": 175942,
#             "CumSecondDose": 2857
#         },
#         {
#             "date": "2021-01-10",
#             "DailyFirstDose": null,
#             "DailySecondDose": null,
#             "CumFirstDose": 163377,
#             "CumSecondDose": 2758
#         }
#     ],
#     "pagination": {
#         "current": "/v1/data?filters=areaType%3Dnation%3BareaName%3Dscotland&structure=%7B%22date%22%3A+%22date%22%2C+%22DailyFirstDose%22%3A+%22newPeopleVaccinatedFirstDoseByPublishDate%22%2C+%22DailySecondDose%22%3A+%22newPeopleVaccinatedSecondDoseByPublishDate%22%2C+%22CumFirstDose%22%3A+%22cumPeopleVaccinatedFirstDoseByPublishDate%22%2C+%22CumSecondDose%22%3A+%22cumPeopleVaccinatedSecondDoseByPublishDate%22%7D&format=json&page=1",
#         "next": null,
#         "previous": null,
#         "first": "/v1/data?filters=areaType%3Dnation%3BareaName%3Dscotland&structure=%7B%22date%22%3A+%22date%22%2C+%22DailyFirstDose%22%3A+%22newPeopleVaccinatedFirstDoseByPublishDate%22%2C+%22DailySecondDose%22%3A+%22newPeopleVaccinatedSecondDoseByPublishDate%22%2C+%22CumFirstDose%22%3A+%22cumPeopleVaccinatedFirstDoseByPublishDate%22%2C+%22CumSecondDose%22%3A+%22cumPeopleVaccinatedSecondDoseByPublishDate%22%7D&format=json&page=1",
#         "last": "/v1/data?filters=areaType%3Dnation%3BareaName%3Dscotland&structure=%7B%22date%22%3A+%22date%22%2C+%22DailyFirstDose%22%3A+%22newPeopleVaccinatedFirstDoseByPublishDate%22%2C+%22DailySecondDose%22%3A+%22newPeopleVaccinatedSecondDoseByPublishDate%22%2C+%22CumFirstDose%22%3A+%22cumPeopleVaccinatedFirstDoseByPublishDate%22%2C+%22CumSecondDose%22%3A+%22cumPeopleVaccinatedSecondDoseByPublishDate%22%7D&format=json&page=1"
#     }
# }
#
# Scraped data in table format:
#             DailyFirstDose  DailySecondDose  CumFirstDose  CumSecondDose
# date
# 2021-01-10             NaN              NaN        163377           2758
# 2021-01-11         12565.0             99.0        175942           2857
# 2021-01-12         16023.0            133.0        191965           2990
# 2021-01-13         16242.0            200.0        208207           3190
# 2021-01-14         16633.0            141.0        224840           3331
# 2021-01-15             0.0              0.0        224840           3331
# 2021-01-16             0.0              0.0        224840           3331
# 2021-01-17         40151.0            367.0        264991           3698
# 2021-01-18         19591.0            188.0        284582           3886
# 2021-01-19         25327.0            284.0        309909           4170
# 2021-01-20         24962.0            296.0        334871           4466
# 2021-01-21         23583.0            223.0        358454           4689
# 2021-01-22         22213.0            499.0        380667           5188
# 2021-01-23         23371.0            195.0        404038           5383
# 2021-01-24         11364.0            155.0        415402           5538
# 2021-01-25         22498.0            522.0        437900           6060
# 2021-01-26         24192.0            536.0        462092           6596
# 2021-01-27         29566.0            187.0        491658           6783
# 2021-01-28         24197.0            312.0        515855           7095
# 2021-01-29         27515.0            543.0        543370           7638
# 2021-01-30         22899.0            156.0        566269           7794
# 2021-01-31          9628.0             55.0        575897           7849
# 2021-02-01         34881.0            496.0        610778           8345
# 2021-02-02         38484.0            413.0        649262           8758
# 2021-02-03         45085.0            273.0        694347           9031
# 2021-02-04         48165.0            498.0        742512           9529
